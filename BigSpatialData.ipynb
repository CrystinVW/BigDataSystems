# %% [markdown]
# <h1 style='text-aling:center;color:Navy'>  Big Data Systems - Crystin VanWagenen </h1>

# %% [markdown]
# # <span style="color:#3665af">Big Spatial Data </span><span style="font-size:15px">(Estimated time: 4 hours) </span>
#
# <hr>
# In this section, we will practice how to use a Hadoop-based system to analyze and visualize spatial data.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">Disclaimer </div>
#
# This assignment is based on GeoJinni, formerly known as Spatial Hadoop. This system extends Hadoop by adding new classes with new functionality.
#
# The assignment is structured as follows. The first section describe the installation process, which will be based on a Ubuntu 16.04 system. In section 2 we will learn basic commands of Spatial Hadoop. In section 3 we will use Pigeon, a pig extension for querying spatial data. and in the last section 4, we will use tools for visualizing the obtained results.

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">Section 1 - Environment Set Up </div>
#
# As mentioned before, this assignment will run on Spatial Hadoop. This section presents a guideline to install all the necessary tools to run the assignment.
#
# This guide is based on Ubuntu 16 desktop. If you are using another system, you can either use this guide as guideline and research online how to install all the packages in your system, or use a virtual machine. We recommend the latter.
#
# The required packages are:
# - Java 8
# - Hadoop 2.7.6
# - Spatial Hadoop
# - Pig
# - Pigeon 0.2.1

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1. Install Java 8</div>
# Open a terminal, and run the following commands one by one.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px darkred;">
# sudo su -
# add-apt-repository ppa:webupd8team/java
# apt update
# apt install oracle-java-8-installer
# </pre>
# You can find a detailed guide here: http://www.webupd8.org/

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">2. Install Hadoop</div>
# In this assignment, we will use a single Hadoop node. In other words, we will not set up a cluster.
# For this kind of environmnet, the installation process is just downloaded and do minor configurations.
#
# We will assume the current user is _bigdata_.
#
# Open a web browser and download Hadoop 2.7.6. Note the version, as this is important.
# - A [direct download link](http://apache.mirrors.pair.com/hadoop/common/hadoop-2.7.6/hadoop-2.7.6.tar.gz).
# - A detailed [installation guide](http://hadoop.apache.org/docs/r2.7.2/hadoop-project-dist/hadoop-common/SingleCluster.html) is available.
#
# Once the file is downloaded, on the same terminal you used to install java (running commandas as root):
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px darkred;">
# apt install ssh
# apt install rsync
# </pre>
#
# Once that is done, open a new terminal (with the user _bigdata_):
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~
# mkdir Hadoop
# cd Hadoop  #this is going to be our woriking directory
# tar xvf ~/Downloads/hadoop-2.7.6.tar.gz
# </pre>
#
# We need to add the JAVA_HOME variable for Hadoop. To do that we will edit the configuration file.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop/hadoop-2.7.6/etc/hadoop
# vi hadoop-env/sh  # you can use nano if you prefer.
# </pre>
#
# Add the following line:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px darkgreen;">
# export JAVA_HOME=/usr/lib/jvm/java-8-oracle/jre/
# </pre>
#
# We are using this as a Stand-Alone server. Let's test our installation:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# ~/Hadoop/hadoop-2.7.6/bin/hadoop version
# </pre>
#
# The output should be like this:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px black;">
# Hadoop 2.7.6
# Subversion https://shv@git-wip-us.apache.org/repos/asf/hadoop.git -r 085099c66cf28be31604560c376fa282e69282b8
# Compiled by kshvachk on 2018-04-18T01:33Z
# Compiled with protoc 2.5.0
# From source with checksum 71e2695531cb3360ab74598755d036
# This command was run using /home/bigdata/Hadoop/hadoop-2.7.6/share/hadoop/common/hadoop-common-2.7.6.jar
# </pre>

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">3. Install Spatial Hadoop</div>
# As Spatial Hadoop is packed as a library (.jar) we need to download the software and copy it to the Hadoop installation directory.
#
# Open a web browser and download Spatial Hadoop from [Spatial Hadoop Website](http://spatialhadoop.cs.umn.edu/)
# - A [direct download link](http://spatialhadoop.cs.umn.edu/downloads/spatialhadoop-2.4.2-bin.tar.gz).
#
# Once you download the software, using the same terminal you used to install Hadoop (with the user _bigdata_) do the following:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop/hadoop-2.7.6
# tar xvf ~/Downloads/spatialhadoop-2.4.2-bin.tar.gz
# </pre>
#
# To test the installation run the following commands:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# ~/Hadoop/hadoop-2.7.6/bin/shadoop
# </pre>
#
# The output should look like this:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px black;">
# An example program must be given as the first argument.
# Valid program names are:
#   closestpair: Computes the closest pair of point of an input set of points
#   convexhull: Computes the convex hull of an input set of points
#   delaunay: Computes the Delaunay triangulation for a set of points
#   distcp: Copies a directory or file using a MapReduce job
#   dj: Computes the spatial join between two input files using the distributed join algorithm
#   farthestpair: Computes the farthest pair of point of an input set of points
#   generate: Generates a random file containing spatial data
#   gplot: Plots a file to an image
#   hadoopviz: Run Hadoopviz Server
#   hdfplot: Plots a heat map for a give NASA dataset
#   hdfx: Extracts data from a set of HDF files to text files
#   hplot: Plots a heat map to an image
#   index: Spatially index a file using a specific indexer
#   knn: Finds the k nearest neighbor in a file to a point
#   lakesplot: Plots lakes to SVG image
#   mbr: Finds the minimal bounding rectangle of an input file
#   mplot: Plot using ImageMagick
#   multihdfplot: Plots NASA datasets in the spatiotemporal range provided by user
#   oldindex: Spatially index a file using a specific indexer
#   rangequery: Finds all objects in the query range given by a rectangle
#   readfile: Retrieve some information about the index of a file
#   sample: Reads a random sample from the input file
#   shahedindexer: Creates a multilevel spatio-temporal indexer for NASA data
#   sjmr: Computes the spatial join between two input files using the SJMR algorithm
#   skyline: Computes the skyline of an input set of points
#   staggquery: Runs a spatio temporal aggregate query on HDF files
#   union: Computes the union of input shapes
#   uunion: Computes the union of input shapes using the UltimateUnion algorithm
#   vizserver: Starts a server that handles visualization requests
# </pre>
#
# Which is the Spatial Hadoop online help.

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">4. Install Pig</div>
#
# Open a web browser and download the lastest version of PIG (0.17) of Pig from the [website](http://pig.apache.org/)
# - A [direct download link](http://mirrors.gigenet.com/apache/pig/pig-0.17.0/pig-0.17.0.tar.gz).
# - A detailed [documentation](http://pig.apache.org/docs/r0.17.0/start.html) is available.
#
# Once the file is downloaded, open a new terminal (with the user _bigdata_):
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# tar xvf ~/Downloads/pig-0.17.0.tar.gz
# </pre>
#
# We need to add the PIG path to our enviroment path. To do that we will edit bash resource config file.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# vi ~/.bashrc
# </pre>
#
# At the end of the file add:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px darkgreen;">
# export PATH=/home/bigdata/Hadoop/pig-0.17.0/bin:$PATH
# </pre>
#
# Let's re-load and test the enviroment.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# . ~/.bashrc
# pig -help
# </pre>
#
# The output should look like this:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px black;">
# Apache Pig version 0.17.0 (r1797386)
# compiled Jun 02 2017, 15:41:58
#
# USAGE: Pig [options] [-] : Run interactively in grunt shell.
#        Pig [options] -e[xecute] cmd [cmd ...] : Run cmd(s).
#        Pig [options] [-f[ile]] file : Run cmds found in file.
#   options include:
#     -4, -log4jconf - Log4j configuration file, overrides log conf
#     -b, -brief - Brief logging (no timestamps)
#     -c, -check - Syntax check
#     -d, -debug - Debug level, INFO is default
#     -e, -execute - Commands to execute (within quotes)
#     -f, -file - Path to the script to execute
#     -g, -embedded - ScriptEngine classname or keyword for the ScriptEngine
#     -h, -help - Display this message. You can specify topic to get help for that topic.
#         properties is the only topic currently supported: -h properties.
#     -i, -version - Display version information
#     -l, -logfile - Path to client side log file; default is current working directory.
#     -m, -param_file - Path to the parameter file
#     -p, -param - Key value pair of the form param=val
#     -r, -dryrun - Produces script with substituted parameters. Script is not executed.
#     -t, -optimizer_off - Turn optimizations off. The following values are supported:
#             ConstantCalculator - Calculate constants at compile time
#             SplitFilter - Split filter conditions
#             PushUpFilter - Filter as early as possible
#             MergeFilter - Merge filter conditions
#             PushDownForeachFlatten - Join or explode as late as possible
#             LimitOptimizer - Limit as early as possible
#             ColumnMapKeyPrune - Remove unused data
#             AddForEach - Add ForEach to remove unneeded columns
#             MergeForEach - Merge adjacent ForEach
#             GroupByConstParallelSetter - Force parallel 1 for "group all" statement
#             PartitionFilterOptimizer - Pushdown partition filter conditions to loader implementing LoadMetaData
#             PredicatePushdownOptimizer - Pushdown filter predicates to loader implementing LoadPredicatePushDown
#             All - Disable all optimizations
#         All optimizations listed here are enabled by default. Optimization values are case insensitive.
#     -v, -verbose - Print all error messages to screen
#     -w, -warning - Turn warning logging on; also turns warning aggregation off
#     -x, -exectype - Set execution mode: local|mapreduce|tez, default is mapreduce.
#     -F, -stop_on_failure - Aborts execution on the first failed job; default is off
#     -M, -no_multiquery - Turn multiquery optimization off; default is on
#     -N, -no_fetch - Turn fetch optimization off; default is on
#     -P, -propertyFile - Path to property file
#     -printCmdDebug - Overrides anything else and prints the actual command used to run Pig, including
#                      any environment variables that are set by the pig command.
# 2018-05-03 15:05:07,029 INFO  [main] pig.Main (Main.java:printScriptRunTime(694)) - Pig script completed in 396 milliseconds (396 ms)
#
# </pre>

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">5. Install Pigeon</div>
#
# Open a web browser and download the lastest version of Pigeon (0.2.1) and the configuration.
# - A [direct download link for Pigeon jar file](https://drive.google.com/file/d/1Ly1N8zNtsOEY3k19K6xZZR7IQ1iYgmPI/view?usp=sharing).
# - A [direct download link for the import file](https://drive.google.com/file/d/1E6ujTQg8PoqiaaH_yqvwHrxPzK_h9MLo/view?usp=sharing).
#
# Also, we will need some additional libraries, that we set available for you here:
# - [JTS Topology Suite version 1.8.0](https://drive.google.com/file/d/1i6vR4yMu6v1Gkfc0B7c7XiMf-WofxHxK/view?usp=sharing)
# - [ESRI Geometry API version 2.1.0](https://drive.google.com/file/d/17H798sHj3j_4QMmODDRkMu9up_0_ay9U/view?usp=sharing)
#
# Pigeon [website](http://spatialhadoop.cs.umn.edu/pigeon/).
#
# Once the file is downloaded, open a new terminal (with the user _bigdata_):
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# mv ~/Downloads/pigeon-0.1.jar ~/Hadoop
# mv ~/Downloads/pigeon_import.pig ~/Hadoop
# mv ~/Downloads/jts-1.8.0.jar ~/Hadoop
# mv ~/Downloads/esri-geometry-api-1.1.1.jar ~/Hadoop
# </pre>
#
# That should be all to have Pigeon available.

# %% [markdown]
# ---
#
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">Section 2 - Basic Spatial Hadoop commands. </div>
#
# We can access the basic Spatial Hadoop commands by running the following in a terminal:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ~/Hadoop/bin/shadoop &lt;utility&gt;
# </pre>
#
# To get help, just run the command without any parameters.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ~/Hadoop/bin/shadoop
# </pre>
#
# You can also get help for a particular command by typing the command without parameters, like:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ~/Hadoop/bin/shadoop generate
# </pre>
# will display:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px black;">
# Set MBR of the generated file using rect:&lt;x1,y1,x2,y2&gt;
# Generates a file with random shapes
# Parameters (* marks required parameters):
# &lt;output file&gt; - Path to the file to generate. If omitted, file is generated to stdout.
# mbr:&lt;x1,y1,x2,y2&gt; - (*) The MBR of the generated data. Originated at (x,y) with dimensions (w,h)
# shape:&lt;point|(rectangle)&gt; - Type of shapes in generated file
# sindex:&lt;grid&gt; - Type of global index in generated file. The only supported index is 'grid'
# seed:&lt;s&gt; - Use a specific seed to generate the file
# rectsize:&lt;rs&gt; - Maximum edge size for generated rectangles
# -overwrite - Overwrite output file without notice
# Generic options supported are
# -conf &lt;configuration file&gt;     specify an application configuration file
# -D &lt;property=value&gt;            use value for given property
# -fs &lt;local|namenode:port&gt;      specify a namenode
# -jt &lt;local|resourcemanager:port&gt;    specify a ResourceManager
# -files &lt;comma separated list of files&gt;    specify comma separated files to be copied to the map reduce cluster
# -libjars &lt;comma separated list of jars&gt;    specify comma separated jar files to include in the classpath.
# -archives &lt;comma separated list of archives&gt;    specify comma separated archives to be unarchived on the compute machines.
#
# The general command line syntax is
# bin/hadoop command [genericOptions] [commandOptions]
# <pre>

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1. Generating Random Shapes</div>
#
# Let's start simple. Let's generate random rectangles within the bounding box defined by _[ (0,0), (10000,10000) ]_.
# To do this we use the **generate** Spatial Hadoop command.
#
# We will create 200mb file, named test1, filled with rectangles. In a terminal type the following command:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
#  ~/Hadoop/hadoop-2.7.6/bin/shadoop generate test1 mbr:0,0,10000,10000 size:200.mb shape:rect -overwrite
# </pre>

# %% [raw]
# 21261 [main] INFO  org.apache.hadoop.mapreduce.Job  - Job job_local636186859_0001 completed successfully
# 21262 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - PrivilegedAction as:bigdata (auth:SIMPLE) from:org.apache.hadoop.mapreduce.Job.getCounters(Job.java:758)
# 21331 [main] INFO  org.apache.hadoop.mapreduce.Job  - Counters: 15
# 	File System Counters
# 		FILE: Number of bytes read=23079721
# 		FILE: Number of bytes written=946849062
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=2892033
# 		Map output records=2892033
# 		Input split bytes=539
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=436
# 		Total committed heap usage (bytes)=440860672
# 	File Input Format Counters
# 		Bytes Read=0
# 	File Output Format Counters
# 		Bytes Written=211354136

# %% [markdown]
# Let's inspect the output
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ls -al ~/Hadoop/test1
# head -20 ~/Hadoop/test1/part-00000_data_00001 | nl
# </pre>

# %% [raw]
# bigdata@bigdata-VirtualBox:~/Hadoop$ ls -al ~/Hadoop/test1
# total 206448
# drwxr-xr-x 2 bigdata bigdata     4096 May 10 07:33 .
# drwxr-xr-x 5 bigdata bigdata     4096 May 10 07:33 ..
# -rw-r--r-- 1 bigdata bigdata      678 May 10 07:33 _master.heap
# -rw-r--r-- 1 bigdata bigdata       16 May 10 07:33 ._master.heap.crc
# -rw-r--r-- 1 bigdata bigdata 33554391 May 10 07:32 part-00000_data_00001
# -rw-r--r-- 1 bigdata bigdata   262152 May 10 07:32 .part-00000_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata 33554393 May 10 07:32 part-00001_data_00001
# -rw-r--r-- 1 bigdata bigdata   262152 May 10 07:32 .part-00001_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata 33554374 May 10 07:32 part-00002_data_00001
# -rw-r--r-- 1 bigdata bigdata   262152 May 10 07:32 .part-00002_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata 33554362 May 10 07:32 part-00003_data_00001
# -rw-r--r-- 1 bigdata bigdata   262152 May 10 07:32 .part-00003_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata 33554425 May 10 07:32 part-00004_data_00001
# -rw-r--r-- 1 bigdata bigdata   262152 May 10 07:32 .part-00004_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata 33554369 May 10 07:32 part-00005_data_00001
# -rw-r--r-- 1 bigdata bigdata   262152 May 10 07:32 .part-00005_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata  8388604 May 10 07:32 part-00006_data_00001
# -rw-r--r-- 1 bigdata bigdata    65544 May 10 07:32 .part-00006_data_00001.crc
# -rw-r--r-- 1 bigdata bigdata        0 May 10 07:32 _SUCCESS
# -rw-r--r-- 1 bigdata bigdata        8 May 10 07:32 ._SUCCESS.crc
# bigdata@bigdata-VirtualBox:~/Hadoop$ head -20 ~/Hadoop/test1/part-00000_data_00001 | n1
# n1: command not found
# bigdata@bigdata-VirtualBox:~/Hadoop$ head -20 ~/Hadoop/test1/part-00000_data_00001 | nl
#      1	326.1817388346688,5460.776521830376,411.1817388346688,5550.776521830376
#      2	4763.233009262436,4926.861668485009,4816.233009262436,4981.861668485009
#      3	2874.937621554882,8945.361065995257,2901.937621554882,9006.361065995257
.apache.hadoop.mapreduce.lib.output.FileOutputCommitter  - Merging data from DeprecatedRawLocalFileStatus{path=file:/home/bigdata/Hadoop/test1.idx.grid/_temporary/0/task_local1520958330_0002_r_000000/_master_0.grid; isDirectory=false; length=511; replication=1; blocksize=33554432; modification_time=1525961823000; access_time=0; owner=; group=; permission=rw-rw-rw-; isSymlink=false} to file:/home/bigdata/Hadoop/test1.idx.grid/_master_0.grid
# 34624 [Thread-50] DEBUG org.apache.hadoop.security.UserGroupInformation  - PrivilegedAction as:bigdata (auth:SIMPLE) from:org.apache.hadoop.fs.FileContext.getAbstractFileSystem(FileContext.java:331)
# 38711 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - PrivilegedAction as:bigdata (auth:SIMPLE) from:org.apache.hadoop.mapreduce.Job.updateStatus(Job.java:320)
# 38712 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - PrivilegedAction as:bigdata (auth:SIMPLE) from:org.apache.hadoop.mapreduce.Job.updateStatus(Job.java:320)
# Total indexing time in millis 37265

# %% [markdown]
# <div style="font-size:20px;background-color:#A74A54;color:#F1E6E7;padding:10px;">
#     Question 2.2.1:
# </div>
#
# **How long did the indexing take?**

# %% [raw]
# The total indexing time took 37265 milliseconds.

# %% [markdown]
# Let's inspect the output
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ls -al ~/Hadoop/test1.idx.grid
# head -20 ~/Hadoop/test1.idx.grid/part-00000 | nl
# </pre>
#
# Also we can inspect the index by using a _shadoop_ command:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ~/Hadoop/hadoop-2.7.6/bin/shadoop readfile test1.idx.grid
# </pre>

# %% [raw]
# bigdata@bigdata-VirtualBox:~/Hadoop$ ls -al ~/Hadoop/test1.idx.grid
# total 209660
# drwxr-xr-x 2 bigdata bigdata     4096 May 10 08:17 .
# drwxr-xr-x 6 bigdata bigdata     4096 May 10 08:17 ..
# -rw-r--r-- 1 bigdata bigdata      828 May 10 08:17 _grid.wkt
# -rw-r--r-- 1 bigdata bigdata       16 May 10 08:17 ._grid.wkt.crc
# -rw-r--r-- 1 bigdata bigdata      511 May 10 08:17 _master.grid
# -rw-r--r-- 1 bigdata bigdata       12 May 10 08:17 ._master.grid.crc
# -rw-r--r-- 1 bigdata bigdata 35621668 May 10 08:16 part-00000
# -rw-r--r-- 1 bigdata bigdata   278304 May 10 08:16 .part-00000.crc
# -rw-r--r-- 1 bigdata bigdata 35760724 May 10 08:16 part-00001
# -rw-r--r-- 1 bigdata bigdata   279392 May 10 08:16 .part-00001.crc
# -rw-r--r-- 1 bigdata bigdata 35406056 May 10 08:16 part-00002
# -rw-r--r-- 1 bigdata bigdata   276620 May 10 08:16 .part-00002.crc
# -rw-r--r-- 1 bigdata bigdata 35364726 May 10 08:17 part-00003
# -rw-r--r-- 1 bigdata bigdata   276296 May 10 08:17 .part-00003.crc
# -rw-r--r-- 1 bigdata bigdata 35571141 May 10 08:17 part-00004
# -rw-r--r-- 1 bigdata bigdata   277908 May 10 08:17 .part-00004.crc
# -rw-r--r-- 1 bigdata bigdata 35250430 May 10 08:17 part-00005
# -rw-r--r-- 1 bigdata bigdata   275404 May 10 08:17 .part-00005.crc
# 439  [main] DEBUG org.apache.hadoop.metrics2.impl.MetricsSystemImpl  - UgiMetrics, User and group related metrics
# 573  [main] DEBUG org.apache.hadoop.security.authentication.util.KerberosName  - Kerberos krb5 configuration not found, setting default realm to empty
# 577  [main] DEBUG org.apache.hadoop.security.Groups  -  Creating new Groups object
# 584  [main] DEBUG org.apache.hadoop.util.NativeCodeLoader  - Trying to load the custom-built native-hadoop library...
# 590  [main] DEBUG org.apache.hadoop.util.NativeCodeLoader  - Loaded the native-hadoop library
# 592  [main] DEBUG org.apache.hadoop.security.JniBasedUnixGroupsMapping  - Using JniBasedUnixGroupsMapping for Group resolution
# 597  [main] DEBUG org.apache.hadoop.security.JniBasedUnixGroupsMappingWithFallback  - Group mapping impl=org.apache.hadoop.security.JniBasedUnixGroupsMapping
# 795  [main] DEBUG org.apache.hadoop.security.Groups  - Group mapping impl=org.apache.hadoop.security.JniBasedUnixGroupsMappingWithFallback; cacheTimeout=300000; warningDeltaMs=5000
# 806  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - hadoop login
# 812  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - hadoop login commit
# 831  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - using local user:UnixPrincipal: bigdata
# 833  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - Using user: "UnixPrincipal: bigdata" with name bigdata
# 833  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - User entry: "bigdata"
# 833  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - Assuming keytab is managed externally since logged in from subject.
# 834  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - UGI loginUser:bigdata (auth:SIMPLE)
# 1349 [main] INFO  edu.umn.cs.spatialHadoop.OperationsParams  - Autodetected shape 'rect' for input '8820.476204257831,7586.451365488375,8909.476204257831,7635.451365488375'
# Cell #0 Rectangle: (0.0025640492340439636,1.549486339236239E-4)-(3333.3333333333335,5000.0) --- 35621668
# Cell #1 Rectangle: (3333.3333333333335,0.012539652990417594)-(6666.666666666667,5000.0) --- 35760724
# Cell #2 Rectangle: (6666.666666666667,0.016016773312088617)-(10000.0,5000.0) --- 35406056
# Cell #3 Rectangle: (0.0036258797919686003,5000.0)-(3333.3333333333335,10000.0) --- 35364726
# Cell #4 Rectangle: (3333.3333333333335,5000.0)-(6666.666666666667,10000.0) --- 35571141
# Cell #5 Rectangle: (6666.666666666667,5000.0)-(10000.0,10000.0) --- 35250430

# %% [markdown]
# <div style="font-size:20px;background-color:#A74A54;color:#F1E6E7;padding:10px;">
#     Question 2.2.2:
# </div>
#
# **How do you interpret each line of the file?**

# %% [raw]
# Each line represent a rectangle. Those rectangles may come into use later, when querying a particular region.

# %% [markdown]
# <div style="font-size:20px;background-color:#0B6713;color:#F1E6E7;padding:10px;">
#     TO-DO 2.2.3:
# </div>
#
# a) **Create a quadtree index named test1.idx.quad.**
# b) **Inspect one of your output files (like we did before). Place a sample of the output below.**

# %% [raw]
# a) Place your command line here.
# bigdata@bigdata-VirtualBox:~/Hadoop$ ~/Hadoop/hadoop-2.7.6/bin/shadoop index test1 test1.idx.quadtree mbr:0,0,10000,10000 sindex:quadtree shape:rect

# %% [raw]
# b) Place the first 20 lines of each inspect command.
# bigdata@bigdata-VirtualBox:~/Hadoop$ ls -al ~/Hadoop/test1.idx.quadtree
# -rw-r--r-- 1 bigdata bigdata       28 May 10 08:26 ._quadtree.wkt.crc
#
# bigdata@bigdata-VirtualBox:~/Hadoop$ head -20 ~/Hadoop/test1.idx.quadtree/part-00016 | nl
#      1	941.1146394468417,772.2453480397262,968.1146394468417,798.2453480397262
#      2	1533.451635483295,1530.724667864265,1596.451635483295,1560.724667864265
#      3	1587.3908357782784,1753.2898615021763,1624.3908357782784,1784.2898615021763
#      4	2218.5502281243,443.2749503921862,2250.5502281243,520.2749503921862
#      5	225.8417604870644,1330.082074643446,275.8417604870644,1338.082074643446
#      6	2131.883911733956,36.13696206843042,2171.883911733956,117.13696206843042
#      7	674.0967920677721,1669.9343671358836,772.0967920677721,1685.9343671358836
#      8	1293.7281829258895,1997.44316603101,1328.7281829258895,2067.44316603101
#      9	785.5625650524123,493.7358205593867,840.5625650524123,566.7358205593866
#     10	1771.5573693866515,1576.7098315089213,1852.5573693866515,1618.7098315089213
#     11	2221.8571028782308,1675.8031762430758,2293.8571028782308,1761.8031762430758
#     12	1330.038786581449,1828.136335538385,1398.038786581449,1868.136335538385
#     13	1267.9967679904935,2114.707760273028,1279.9967679904935,2171.707760273028
#     14	1956.937530368662,873.6849171708805,2049.937530368662,924.6849171708805
#     15	1269.4591983484027,2143.798046609122,1281.4591983484027,2212.798046609122
#     16	1173.7626196269168,486.4229434871992,1191.7626196269168,508.4229434871992
#     17	224.09629983013767,230.49178632524757,279.0962998301377,284.4917863252476
#     18	1458.2775944794046,16.889544946269154,1485.2775944794046,30.889544946269154
#     19	1667.2036006858336,675.3622395827886,1679.2036006858336,722.3622395827886
#     20	1452.5690409657577,919.4899709991322,1473.5690409657577,1003.4899709991322

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">3. Query the data</div>
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ~/Hadoop/hadoop-2.7.6/bin/shadoop knn test1.idx.grid knn_results point:1000,1000 k:1000 shape:rect
# head -20 ~/Hadoop/knn_results |nl
# </pre>

# %% [raw]
# bigdata@bigdata-VirtualBox:~/Hadoop$ ~/Hadoop/hadoop-2.7.6/bin/shadoop knn test1.idx.grid knn_results point:1000,1000 k:1000 shape:rect
# 0    [main] DEBUG org.apache.hadoop.util.Shell  - setsid exited with exit code 0
# 381  [main] DEBUG org.apache.hadoop.util.NativeCodeLoader  - Trying to load the custom-built native-hadoop library...
# 400  [main] DEBUG org.apache.hadoop.util.NativeCodeLoader  - Loaded the native-hadoop library
# 717  [main] DEBUG org.apache.hadoop.metrics2.lib.MutableMetricsFactory  - field org.apache.hadoop.metrics2.lib.MutableRate org.apache.hadoop.security.UserGroupInformation$UgiMetrics.loginSuccess with annotation @org.apache.hadoop.metrics2.annotation.Metric(about=, sampleName=Ops, always=false, type=DEFAULT, valueName=Time, value=[Rate of successful kerberos logins and latency (milliseconds)])
# 722  [main] DEBUG org.apache.hadoop.metrics2.lib.MutableMetricsFactory  - field org.apache.hadoop.metrics2.lib.MutableRate org.apache.hadoop.security.UserGroupInformation$UgiMetrics.loginFailure with annotation @org.apache.hadoop.metrics2.annotation.Metric(about=, sampleName=Ops, always=false, type=DEFAULT, valueName=Time, value=[Rate of failed kerberos logins and latency (milliseconds)])
# 722  [main] DEBUG org.apache.hadoop.metrics2.lib.MutableMetricsFactory  - field org.apache.hadoop.metrics2.lib.MutableRate org.apache.hadoop.security.UserGroupInformation$UgiMetrics.getGroups with annotation @org.apache.hadoop.metrics2.annotation.Metric(about=, sampleName=Ops, always=false, type=DEFAULT, valueName=Time, value=[GetGroups])
# 723  [main] DEBUG org.apache.hadoop.metrics2.impl.MetricsSystemImpl  - UgiMetrics, User and group related metrics
# 906  [main] DEBUG org.apache.hadoop.security.authentication.util.KerberosName  - Kerberos krb5 configuration not found, setting default realm to empty
# 908  [main] DEBUG org.apache.hadoop.security.Groups  -  Creating new Groups object
# 916  [main] DEBUG org.apache.hadoop.security.JniBasedUnixGroupsMapping  - Using JniBasedUnixGroupsMapping for Group resolution
# 916  [main] DEBUG org.apache.hadoop.security.JniBasedUnixGroupsMappingWithFallback  - Group mapping impl=org.apache.hadoop.security.JniBasedUnixGroupsMapping
# 981  [main] DEBUG org.apache.hadoop.security.Groups  - Group mapping impl=org.apache.hadoop.security.JniBasedUnixGroupsMappingWithFallback; cacheTimeout=300000; warningDeltaMs=5000
# 988  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - hadoop login
# 990  [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - hadoop login commit
# 1001 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - using local user:UnixPrincipal: bigdata
# 1002 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - Using user: "UnixPrincipal: bigdata" with name bigdata
# 1003 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - User entry: "bigdata"
# 1003 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - Assuming keytab is managed externally since logged in from subject.
# 1004 [main] DEBUG org.apache.hadoop.security.UserGroupInformation  - UGI loginUser:bigdata (auth:SIMPLE)
# 1544 [Thread-4] INFO  edu.umn.cs.spatialHadoop.mapreduce.SpatialRecordReader3  - Open a SpatialRecordReader to split: test1.idx.grid/part-00000:0+35621668
# 3136 [Thread-4] DEBUG org.apache.hadoop.io.nativeio.NativeIO  - Initialized cache for IDs to User/Group mapping with a  cache timeout of 14400 seconds.
# Time for 1 jobs is 1902 millis
# Total iterations: 1
# bigdata@bigdata-VirtualBox:~/Hadoop$ head -20 ~/Hadoop/knn_results | nl
#      1	17.500281091714463,995.5997904994296,983.0619365144622,997.5997904994296,1001.0619365144622
#      2	17.797324891933027,984.8449686906879,992.3311199393636,1003.8449686906879,1009.3311199393636
#      3	21.57997304225873,996.2710826016053,978.7446380519982,999.2710826016053,987.7446380519982
#      4	24.446987713802304,978.0600685535823,995.6677593008101,1024.0600685535824,997.6677593008101
#      5	31.244965928870027,980.2024702401025,975.8275836685237,997.2024702401025,982.8275836685237
#      6	32.34120223413991,993.4379804347537,968.331509963769,1005.4379804347537,1004.331509963769
#      7	32.73128644394012,985.0240368766639,981.1042546855908,991.0240368766639,1029.1042546855908
#      8	33.37245999602229,1001.1435507452381,975.9563491730416,1023.1435507452381,987.9563491730416
#      9	33.37282256405952,984.868349844551,970.2547743416645,994.868349844551,974.2547743416645
#     10	34.16080541047906,976.4745626515859,975.2307766803548,992.4745626515859,1017.2307766803548
#     11	36.750121710992744,968.5696799372167,980.9551469807776,1004.5696799372167,997.9551469807776
#     12	38.728220689449344,984.7914451763285,996.6170596476753,1009.7914451763285,1035.6170596476754
#     13	39.132110453556926,971.3567298701753,973.337570537941,1001.3567298701753,1021.337570537941
#     14	40.44370290899854,999.0673096144698,1032.4141725949776,1009.0673096144698,1039.4141725949776
#     15	40.51209239590066,1006.9508437118968,976.4315565009451,1032.9508437118968,985.4315565009451
#     16	41.30810494167751,960.2092302611732,1001.0929787462297,983.2092302611732,1011.0929787462297
#     17	41.860738317433864,991.441034934848,1002.9128703697432,1041.441034934848,1005.9128703697432
#     18	42.26178904348145,1024.9835190702095,976.2889855421574,1034.9835190702095,995.2889855421574
#     19	42.27640678727837,968.0353471303449,1016.3881738706116,1037.035347130345,1020.3881738706116
#     20	43.61472752252877,988.6295411285196,1026.7180783065255,1015.6295411285196,1040.7180783065255

# %% [markdown]
# <div style="font-size:20px;background-color:#A74A54;color:#F1E6E7;padding:10px;">
#     Question 2.3.1:
# </div>
#
# a) **Explain the shadoop knn command we just issued.**
#
# b) **How do you interpret each line of the output file?**

# %% [raw]
# Place your answer here.
# a) The command grabs the info from the file, and then performs k nearest neighbor on the data. It then sends the output to knn_results.
# b) The knn command finds the nearest 20 neighboring rectangles. This can be used for driving routes amounst endless amounts of applications.

# %% [markdown]
# <div style="font-size:20px;background-color:#0B6713;color:#F1E6E7;padding:10px;">
#     TO-DO 2.1.2:
# </div>
#
# a) **Write the command to run a range query to extract all rectangles within the range _[ (30,500),  (1040,3050)]_.**
#
# b) **Briefly explain the command you issued**
#
# c) **How do you interpret each line of the output file?**

# %% [raw]
# Place your command and answers here.
# a)bigdata@bigdata-VirtualBox:~/Hadoop$ ~/Hadoop/hadoop-2.7.6/bin/shadoop rangequery test1.idx.grid rect:30,50,1040,3050 rangequery.out shape:rect
#
# b) The command I issued use range query. Which queries all of the rectangles within a certain range. That range being: (30,50),(1040,3050). It then sends the results to file rangequery.out.
# c) Each line is a rectangle within the range of retangles.
#
# Also place the first 10 lines of your query results.
# Note: Be careful reading the command output to make sure it runs correctly.
#
# bigdata@bigdata-VirtualBox:~/Hadoop$ head -10 ~/Hadoop/rangequery.out |nl
#      1	451.1548862770731,2489.1069103944087,467.1548862770731,2537.1069103944087
#      2	806.1059382590774,2020.2747012021528,831.1059382590774,2059.2747012021528
#      3	780.6789911507484,842.1807160816319,870.6789911507484,846.1807160816319
#      4	960.9332944641058,2696.361881120697,1057.9332944641058,2758.361881120697
#      5	277.5475019802065,892.8063957132981,322.5475019802065,967.8063957132981
#      6	462.9083073141893,727.9949735438107,533.9083073141893,739.9949735438107
#      7	1031.8500924210205,1951.628280953851,1105.8500924210205,2046.628280953851
#      8	382.455944170792,2945.4413656684787,415.455944170792,2955.4413656684787
#      9	589.3148907973422,2154.5723335839307,639.3148907973422,2235.5723335839307
#     10	72.00634794367832,2817.859677897746,155.00634794367832,2887.859677897746

# %% [markdown]
# ---
#
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">Section 3 - Query the data using Pigeon. </div>
#
# We will use Pigeon, an extension of Pig, to do some more complex queries.

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1. Download the data</div>
#
# Download the following files to your _~/Hadoop_ directory:
#
# - [Trajectories dataset](https://drive.google.com/file/d/1ktK8NuKtYRg1veL4zYusJ-YMUfxe7kMU/view?usp=sharing): containing a single trajectory (i.e. sequence of spatial locations over time).
# - [ZipCodes](https://drive.google.com/open?id=0B1jY75xGiy7eLWhNUll0ZWFRT0U)

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">2. Running a simple query.</div>
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# ls -al
# </pre>
#
# Among your files you should have:
# - pigeon-0.1.jar,
# - esri-geometry-api-1.1.1.jar,
# - jts-1.8.0.jar,
# - pigeon_import.pig file, and
# - the downloaded files in this directory.
#
#
# Let's count how many points are in the trajectory:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# wc -l trajectory.tsv
# </pre>
#
#
# Let's edit a simple query file.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# vi trajectory.pigeon    #you can use nano or other editor of your preference.
# </pre>
#
# and add this content:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px darkgreen;">
# REGISTER pigeon-0.2.1.jar;
# REGISTER jts-1.8.0.jar;
# REGISTER esri-geometry-api-2.1.0.jar;
# IMPORT 'pigeon_import.pig';
#
# points = LOAD 'trajectory.tsv' AS (type, time: datetime, lat:double, lon:double);
# s_points = FOREACH points GENERATE ST_MakePoint(lat, lon) AS point, time;
# points_by_time = ORDER s_points BY time;
# points_grouped = GROUP points_by_time ALL;
# lines = FOREACH points_grouped GENERATE ST_AsText(ST_MakeLine(points_by_time));
# STORE lines INTO 'trajectory';
# </pre>
#
# save the file and then run it
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# pig -x local trajectory.pigeon
# </pre>

# %% [markdown]
# <div style="font-size:20px;background-color:#0B6713;color:#F1E6E7;padding:10px;">
#     TO-DO 3.2.1:
# </div>
#
# **Inspect the output and answer**
#
# a) **How many lines were generated?**
#
# b) **How do you interpret the output?**

# %% [raw]
# bigdata@bigdata-VirtualBox:~/Hadoop/trajectory$ cat part-r-00000
# LINESTRING (47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.01523 6.9320283, 47.0152279 6.9318747, 47.0152409 6.9320949, 47.0152567 6.932251, 47.0152654 6.9323178, 47.0152618 6.9325062, 47.0152853 6.9326305, 47.0153081 6.9329689, 47.0153126 6.9329898, 47.0153392 6.9331401, 47.015358 6.933234, 47.0154 6.9333785, 47.0155224 6.9336217, 47.0156647 6.9338775, 47.015772 6.9341087, 47.0158467 6.9343404, 47.0159392 6.9345344, 47.0160431 6.9347808, 47.0161534 6.9350492, 47.0161609 6.9350672, 47.0162781 6.9353327, 47.0163828 6.9355746, 47.0164858 6.9357572, 47.0166078 6.9359574, 47.016744 6.9361796, 47.0167706 6.9362175, 47.0168291 6.9363161, 47.0168476 6.9363447, 47.0169314 6.9364851, 47.0169913 6.9365756, 47.0171342 6.9368207, 47.0171646 6.936871, 47.017246 6.9370136, 47.0173871 6.9372297, 47.0175386 6.9374732, 47.0176279 6.9375895
, 47.0141272 6.9228086, 47.0140653 6.922658, 47.013945 6.9224883, 47.0138779 6.9224213, 47.01382 6.9223388, 47.0138086 6.9223263, 47.01377 6.9222838, 47.013764 6.9222738, 47.0137441 6.9222349, 47.0137268 6.9222149, 47.0138904 6.9222978, 47.0138593 6.9222454, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332, 47.0339063 6.952332)
#
# a) acutal lines bigdata@bigdata-VirtualBox:~/Hadoop/trajectory$ cat part-r-00000 | wc -l
# 1
# a-part2) What I think you want:
# bigdata@bigdata-VirtualBox:~/Hadoop/trajectory$ cat part-r-00000 | wc -w
# 613
# Take one away from the word linestring, and there are two words to item, then we have 306 lines.
#
#
# B) The results show the path of the coorinates. So each pair of numbers show the current location. Then the next pair, are the t+1 location.

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">3. Running a spatial query.</div>
#
# We will use the Zipcode dataset and Pigeon to run a spatial query to get all the zipcode geometries that are close to Denver, CO.
#
# First, we need to decompress the dataset
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# cd ~/Hadoop
# mv ~/Downloads/ZCTA5.csv.bz2 ~/Hadoop
# bunzip2 ZCTA5.csv.bz2
# </pre>
# The uncompressed file should be around 1Gb.
#
#
# Let's count how many zipcodes we have in the dataset:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# wc -l ZCTA5.csv
# </pre>
#
#
# Let's edit a simple query file.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# vi Denver_zipcodes.pigeon    #you can use nano or other editor of your preference.
# </pre>
#
# and add this content:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px darkgreen;">
# REGISTER pigeon-0.2.1.jar;
# REGISTER jts-1.8.0.jar;
# REGISTER esri-geometry-api-2.1.0.jar;
# IMPORT 'pigeon_import.pig';
#
# -- Load the dataset. We will use only two fields.
# rows = LOAD 'ZCTA5.csv'  USING PigStorage('\t') AS (geometry, zipcode, ignore0,ignore1, ignore2, ignore3, ignore4, ignore5, ignore6, ignore7 );
#
# -- Uncomment if you want to try with less rows.
# -- rows = LIMIT rows 10;
#
# -- Reformat the data to get the zipcode, the geometry as an object, and the geometry as pure text (we will use this later)
# data = FOREACH rows GENERATE zipcode ,ST_GeomFromText( REPLACE(geometry,'"','')) as geometry, REPLACE(geometry,'"','') as geometryWKT ;
#
# -- Filter based on Denver, CO location and a radius of 6 degrees.
# results = FILTER data BY ST_Intersects(ST_Buffer(ST_MakePoint(-104.9903, 39.7392),6), geometry);
#
# -- Generate the export results.
# exports = FOREACH results GENERATE zipcode, geometryWKT;
#
# -- Store the results
# STORE exports INTO 'Denver_zipcodes';
# </pre>
#
# save the file and then run it
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# pig -x local Denver_zipcodes.pigeon
# </pre>

# %%
bigdata@bigdata-VirtualBox:~/Hadoop$ wc -l ZCTA5.csv
33144 ZCTA5.csv

# %% [markdown]
660202,-105.884861 39.657084,-105.887008 39.657944,-105.888215 39.658427,-105.889007 39.658564,-105.890338 39.658794,-105.893945 39.659418,-105.894133 39.659762,-105.894781 39.660948,-105.896812 39.664664,-105.900076 39.664555,-105.903691 39.664435,-105.910753 39.662294,-105.914866 39.66578,-105.919834 39.669347,-105.919955 39.669434,-105.922285 39.670123,-105.92629 39.672985,-105.926681 39.673588,-105.926644 39.67429,-105.926598 39.675203,-105.92703 39.676703,-105.925991 39.678165,-105.925319 39.679113,-105.92516 39.679319,-105.925144 39.679339,-105.9251 39.679399,-105.925085 39.67942))

# %% [markdown]
# <div style="font-size:20px;background-color:#0B6713;color:#F1E6E7;padding:10px;">
#     TO-DO 3.3.2:
# </div>
#
# **Generate a new file, and name it *Colorado_zipcodes.pigeon* based on the Denver_zipcodes.pigeon that generates the geometries for the zipcodes of the State of Colorado.**
# You may use information from the Lab 8 to get the geometry for the State of Colorado.
#
# a) **Place your Colorado_zipcodes.pigeon file contents in the next cell.** *Save the output in Colorado_zipcodes folder*
#
# b) **How many lines were generated?**
#
# c) **List the first 10 results.** You will need to cut each line down to the first 50 characters. To do that use the bash command _cut -b_. Use _man cut_ to learn about this command.

# %% [raw]
# REGISTER pigeon-0.2.1.jar;
# REGISTER jts-1.8.0.jar;
# REGISTER esri-geometry-api-2.1.0.jar;
# IMPORT 'pigeon_import.pig';
#
# -- Load the dataset. We will use only two fields.
# rows = LOAD 'ZCTA5.csv'  USING PigStorage('\t') AS (geometry, zipcode, ignore0,ignore1, ignore2, ignore3, ignore4, ignore5, ignore6, ignore7 );
#
# -- Uncomment if you want to try with less rows.
# -- rows = LIMIT rows 10;
#
# -- Reformat the data to get the zipcode, the geometry as an object, and the geometry as pure text (we will use this later)
# data = FOREACH rows GENERATE zipcode ,ST_GeomFromText( REPLACE(geometry,'"','')) as geometry, REPLACE(geometry,'"','') as geometryWKT ;
#
# -- Filter based on CO location and a radius of 6 degrees.
#
# results = FILTER data BY ST_Intersects(ST_Buffer(ST_MakePoint(-105.7821,39.5501),6), geometry);
#
# -- Generate the export results.
# exports = FOREACH results GENERATE zipcode, geometryWKT;
#
# -- Store the results
# STORE exports INTO 'Colorado_zipcodes';

# %% [raw]
# Total records written : 1442

# %% [raw]
# bigdata@bigdata-VirtualBox:~/Hadoop/Colorado_zipcodes$ cat part-m-00000 | cut -c1-50
# 80476	POLYGON ((-105.925085 39.67942,-105.924979 3
# 80477	POLYGON ((-106.828216 40.4872,-106.828249 40
# 80478	POLYGON ((-105.917472 40.005413,-105.917605
# 80479	POLYGON ((-106.870229 40.094214,-106.869581
# 80480	POLYGON ((-106.68032 40.647986,-106.680142 4
# 80481	POLYGON ((-105.460298 40.124623,-105.459798
# 80482	POLYGON ((-105.790392 39.951959,-105.790496
# 80483	POLYGON ((-106.972306 40.165136,-106.9543 40
# 80487	POLYGON ((-106.81093 40.313293,-106.810984 4
# 80488	POLYGON ((-106.818387 40.448177,-106.818655

# %% [markdown]
# &nbsp;
